# %% [markdown]
# <a href="https://colab.research.google.com/github/Aermax/web/blob/master/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from seaborn import set_style
from seaborn import set_palette

# %%
df = sns.load_dataset('titanic')

# %%
set_style("whitegrid")
set_palette('pastel')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['fare'], bins=30, kde=True)
plt.title("Dist of Prices")
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()
